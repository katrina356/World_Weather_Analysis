# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy 
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url = url + "&q=" + "ushuaia"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -68.3, 'lat': -54.8},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 38.86,
#   'feels_like': 31.6,
#   'temp_min': 38.86,
#   'temp_max': 38.86,
#   'pressure': 1003,
#   'humidity': 70},
#  'visibility': 10000,
#  'wind': {'speed': 11.5, 'deg': 250},
#  'clouds': {'all': 20},
#  'dt': 1627229315,
#  'sys': {'type': 1,
#   'id': 8303,
#   'country': 'AR',
#   'sunrise': 1627216415,
#   'sunset': 1627245933},
#  'timezone': -10800,
#  'id': 3833367,
#  'name': 'Ushuaia',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current_Description": city_weather})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | esfahan
# Processing Record 7 of Set 1 | coihaique
# Processing Record 8 of Set 1 | sioux lookout
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | yialos
# City not found. Skipping...
# Processing Record 11 of Set 1 | talnakh
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | rincon
# Processing Record 15 of Set 1 | pedernales
# Processing Record 16 of Set 1 | angoche
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | yinchuan
# Processing Record 22 of Set 1 | thana
# Processing Record 23 of Set 1 | bengkulu
# Processing Record 24 of Set 1 | luorong
# Processing Record 25 of Set 1 | lagoa
# Processing Record 26 of Set 1 | matagami
# Processing Record 27 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 1 | norman wells
# Processing Record 29 of Set 1 | vao
# Processing Record 30 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | codrington
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | cururupu
# Processing Record 36 of Set 1 | bilma
# Processing Record 37 of Set 1 | mahaicony
# City not found. Skipping...
# Processing Record 38 of Set 1 | provideniya
# Processing Record 39 of Set 1 | aykino
# Processing Record 40 of Set 1 | yirol
# City not found. Skipping...
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | los llanos de aridane
# Processing Record 43 of Set 1 | sitka
# Processing Record 44 of Set 1 | castro
# Processing Record 45 of Set 1 | salta
# Processing Record 46 of Set 1 | tiksi
# Processing Record 47 of Set 1 | ponta do sol
# Processing Record 48 of Set 1 | kuah
# Processing Record 49 of Set 1 | ostrovnoy
# Processing Record 50 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 2 | lianran
# Processing Record 2 of Set 2 | rongcheng
# Processing Record 3 of Set 2 | khatanga
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | huarmey
# Processing Record 6 of Set 2 | soyo
# Processing Record 7 of Set 2 | bethel
# Processing Record 8 of Set 2 | thinadhoo
# Processing Record 9 of Set 2 | urusha
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | parabel
# Processing Record 14 of Set 2 | tefe
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 18 of Set 2 | naze
# Processing Record 19 of Set 2 | carnarvon
# Processing Record 20 of Set 2 | derzhavinsk
# Processing Record 21 of Set 2 | rawson
# Processing Record 22 of Set 2 | hasaki
# Processing Record 23 of Set 2 | nikolskoye
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | kruisfontein
# Processing Record 26 of Set 2 | guantanamo
# Processing Record 27 of Set 2 | hambantota
# Processing Record 28 of Set 2 | deming
# Processing Record 29 of Set 2 | kargasok
# Processing Record 30 of Set 2 | alpena
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | oliveira
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | taikang
# Processing Record 35 of Set 2 | lima
# Processing Record 36 of Set 2 | ola
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | tasiilaq
# Processing Record 40 of Set 2 | touros
# Processing Record 41 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | geraldton
# Processing Record 44 of Set 2 | narsaq
# Processing Record 45 of Set 2 | saldanha
# Processing Record 46 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 2 | cabedelo
# Processing Record 48 of Set 2 | tumarbong
# Processing Record 49 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 3 | aktash
# Processing Record 2 of Set 3 | gejiu
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | warrnambool
# Processing Record 5 of Set 3 | tungkang
# City not found. Skipping...
# Processing Record 6 of Set 3 | grants pass
# Processing Record 7 of Set 3 | luau
# Processing Record 8 of Set 3 | surt
# Processing Record 9 of Set 3 | pacific grove
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | ust-maya
# Processing Record 12 of Set 3 | wajir
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | olafsvik
# Processing Record 15 of Set 3 | leningradskiy
# Processing Record 16 of Set 3 | rio sereno
# Processing Record 17 of Set 3 | bambanglipuro
# Processing Record 18 of Set 3 | souillac
# Processing Record 19 of Set 3 | hilo
# Processing Record 20 of Set 3 | brownsville
# Processing Record 21 of Set 3 | sinnamary
# Processing Record 22 of Set 3 | inongo
# Processing Record 23 of Set 3 | fairbanks
# Processing Record 24 of Set 3 | lebu
# Processing Record 25 of Set 3 | kavaratti
# Processing Record 26 of Set 3 | narrabri
# Processing Record 27 of Set 3 | sola
# Processing Record 28 of Set 3 | rio gallegos
# Processing Record 29 of Set 3 | waipawa
# Processing Record 30 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 31 of Set 3 | shimoda
# Processing Record 32 of Set 3 | faanui
# Processing Record 33 of Set 3 | san lorenzo
# Processing Record 34 of Set 3 | avera
# Processing Record 35 of Set 3 | saskylakh
# Processing Record 36 of Set 3 | coruripe
# Processing Record 37 of Set 3 | isangel
# Processing Record 38 of Set 3 | corum
# Processing Record 39 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 3 | vanavara
# Processing Record 41 of Set 3 | odweyne
# Processing Record 42 of Set 3 | kaitangata
# Processing Record 43 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 44 of Set 3 | zhigansk
# Processing Record 45 of Set 3 | ahipara
# Processing Record 46 of Set 3 | kutum
# Processing Record 47 of Set 3 | carutapera
# Processing Record 48 of Set 3 | bluefields
# Processing Record 49 of Set 3 | sangar
# Processing Record 50 of Set 3 | sovetskiy
# Processing Record 1 of Set 4 | dunedin
# Processing Record 2 of Set 4 | meulaboh
# Processing Record 3 of Set 4 | hermanus
# Processing Record 4 of Set 4 | barrow
# Processing Record 5 of Set 4 | shelburne
# Processing Record 6 of Set 4 | airai
# Processing Record 7 of Set 4 | vestmanna
# Processing Record 8 of Set 4 | yuxia
# Processing Record 9 of Set 4 | chuy
# Processing Record 10 of Set 4 | cape town
# Processing Record 11 of Set 4 | mahajanga
# Processing Record 12 of Set 4 | cherskiy
# Processing Record 13 of Set 4 | tecoanapa
# Processing Record 14 of Set 4 | mount isa
# Processing Record 15 of Set 4 | kodiak
# Processing Record 16 of Set 4 | chepareria
# Processing Record 17 of Set 4 | sambava
# Processing Record 18 of Set 4 | aswan
# Processing Record 19 of Set 4 | kavieng
# Processing Record 20 of Set 4 | flinders
# Processing Record 21 of Set 4 | clyde river
# Processing Record 22 of Set 4 | ribeira grande
# Processing Record 23 of Set 4 | chokurdakh
# Processing Record 24 of Set 4 | ixtapa
# Processing Record 25 of Set 4 | choix
# Processing Record 26 of Set 4 | severo-kurilsk
# Processing Record 27 of Set 4 | kulhudhuffushi
# Processing Record 28 of Set 4 | aklavik
# Processing Record 29 of Set 4 | esperance
# Processing Record 30 of Set 4 | xinyu
# Processing Record 31 of Set 4 | nanortalik
# Processing Record 32 of Set 4 | bardiyah
# Processing Record 33 of Set 4 | axim
# Processing Record 34 of Set 4 | bati
# Processing Record 35 of Set 4 | taltal
# Processing Record 36 of Set 4 | ucluelet
# Processing Record 37 of Set 4 | macon
# Processing Record 38 of Set 4 | upernavik
# Processing Record 39 of Set 4 | outlook
# Processing Record 40 of Set 4 | itarema
# Processing Record 41 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 4 | kerema
# Processing Record 43 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 44 of Set 4 | mersing
# Processing Record 45 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 4 | ubaitaba
# Processing Record 47 of Set 4 | panalingaan
# Processing Record 48 of Set 4 | ponta delgada
# Processing Record 49 of Set 4 | lubuagan
# Processing Record 50 of Set 4 | moose factory
# Processing Record 1 of Set 5 | riyadh
# Processing Record 2 of Set 5 | bowen
# Processing Record 3 of Set 5 | mar del plata
# Processing Record 4 of Set 5 | vihti
# Processing Record 5 of Set 5 | cranbrook
# Processing Record 6 of Set 5 | sicamous
# Processing Record 7 of Set 5 | erdenet
# Processing Record 8 of Set 5 | necochea
# Processing Record 9 of Set 5 | cedar city
# Processing Record 10 of Set 5 | biak
# Processing Record 11 of Set 5 | monaragala
# Processing Record 12 of Set 5 | beloretsk
# Processing Record 13 of Set 5 | along
# Processing Record 14 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 5 | yaypan
# Processing Record 17 of Set 5 | chara
# Processing Record 18 of Set 5 | hamilton
# Processing Record 19 of Set 5 | tessalit
# Processing Record 20 of Set 5 | luderitz
# Processing Record 21 of Set 5 | vila
# Processing Record 22 of Set 5 | port elizabeth
# Processing Record 23 of Set 5 | waingapu
# Processing Record 24 of Set 5 | dalmau
# Processing Record 25 of Set 5 | namibe
# Processing Record 26 of Set 5 | torbay
# Processing Record 27 of Set 5 | salinopolis
# Processing Record 28 of Set 5 | alofi
# Processing Record 29 of Set 5 | tsabong
# Processing Record 30 of Set 5 | saint george
# Processing Record 31 of Set 5 | camopi
# Processing Record 32 of Set 5 | linxia
# Processing Record 33 of Set 5 | port lincoln
# Processing Record 34 of Set 5 | kapaa
# Processing Record 35 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 5 | mazamari
# Processing Record 37 of Set 5 | yerbogachen
# Processing Record 38 of Set 5 | santa helena de goias
# Processing Record 39 of Set 5 | beira
# Processing Record 40 of Set 5 | marsh harbour
# Processing Record 41 of Set 5 | arman
# Processing Record 42 of Set 5 | quatre cocos
# Processing Record 43 of Set 5 | yar-sale
# Processing Record 44 of Set 5 | bababe
# City not found. Skipping...
# Processing Record 45 of Set 5 | tilichiki
# Processing Record 46 of Set 5 | bubaque
# Processing Record 47 of Set 5 | katsuura
# Processing Record 48 of Set 5 | valparaiso
# Processing Record 49 of Set 5 | timra
# Processing Record 50 of Set 5 | makakilo city
# Processing Record 1 of Set 6 | hutchinson
# Processing Record 2 of Set 6 | mozarlandia
# Processing Record 3 of Set 6 | aykhal
# Processing Record 4 of Set 6 | sao joao da barra
# Processing Record 5 of Set 6 | muros
# Processing Record 6 of Set 6 | cidreira
# Processing Record 7 of Set 6 | borzya
# Processing Record 8 of Set 6 | ilhabela
# Processing Record 9 of Set 6 | san patricio
# Processing Record 10 of Set 6 | mayskiy
# Processing Record 11 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 6 | lompoc
# Processing Record 13 of Set 6 | lavrentiya
# Processing Record 14 of Set 6 | nhulunbuy
# Processing Record 15 of Set 6 | papara
# Processing Record 16 of Set 6 | vaitape
# Processing Record 17 of Set 6 | adrar
# Processing Record 18 of Set 6 | boende
# Processing Record 19 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 6 | ginda
# Processing Record 21 of Set 6 | saint albans
# Processing Record 22 of Set 6 | high level
# Processing Record 23 of Set 6 | richards bay
# Processing Record 24 of Set 6 | acapulco
# Processing Record 25 of Set 6 | maryville
# Processing Record 26 of Set 6 | puerto del rosario
# Processing Record 27 of Set 6 | pevek
# Processing Record 28 of Set 6 | port blair
# Processing Record 29 of Set 6 | tura
# Processing Record 30 of Set 6 | washington
# Processing Record 31 of Set 6 | laramie
# Processing Record 32 of Set 6 | broome
# Processing Record 33 of Set 6 | colwyn bay
# Processing Record 34 of Set 6 | khani
# Processing Record 35 of Set 6 | cayenne
# Processing Record 36 of Set 6 | saint-philippe
# Processing Record 37 of Set 6 | portland
# Processing Record 38 of Set 6 | port augusta
# Processing Record 39 of Set 6 | batagay-alyta
# Processing Record 40 of Set 6 | udachnyy
# Processing Record 41 of Set 6 | tsiroanomandidy
# Processing Record 42 of Set 6 | ugoofaaru
# Processing Record 43 of Set 6 | paamiut
# Processing Record 44 of Set 6 | khuzhir
# Processing Record 45 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 6 | iisalmi
# Processing Record 47 of Set 6 | gelnica
# Processing Record 48 of Set 6 | aberdeen
# Processing Record 49 of Set 6 | vostok
# Processing Record 50 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 1 of Set 7 | hovd
# Processing Record 2 of Set 7 | samfya
# Processing Record 3 of Set 7 | hailar
# Processing Record 4 of Set 7 | iqaluit
# Processing Record 5 of Set 7 | malyye derbety
# Processing Record 6 of Set 7 | bambous virieux
# Processing Record 7 of Set 7 | calama
# Processing Record 8 of Set 7 | vega de alatorre
# Processing Record 9 of Set 7 | muktsar
# Processing Record 10 of Set 7 | guanica
# Processing Record 11 of Set 7 | bjornevatn
# Processing Record 12 of Set 7 | kangaatsiaq
# Processing Record 13 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 7 | rodino
# Processing Record 15 of Set 7 | tarko-sale
# Processing Record 16 of Set 7 | flin flon
# Processing Record 17 of Set 7 | cabo san lucas
# Processing Record 18 of Set 7 | bathsheba
# Processing Record 19 of Set 7 | konakovo
# Processing Record 20 of Set 7 | dali
# Processing Record 21 of Set 7 | lawang
# Processing Record 22 of Set 7 | coahuayana
# Processing Record 23 of Set 7 | mehamn
# Processing Record 24 of Set 7 | mandalgovi
# Processing Record 25 of Set 7 | ahuimanu
# Processing Record 26 of Set 7 | santa vitoria do palmar
# Processing Record 27 of Set 7 | qaqortoq
# Processing Record 28 of Set 7 | touho
# Processing Record 29 of Set 7 | melito di porto salvo
# Processing Record 30 of Set 7 | aurora
# Processing Record 31 of Set 7 | popondetta
# Processing Record 32 of Set 7 | jiuquan
# Processing Record 33 of Set 7 | roblin
# Processing Record 34 of Set 7 | fare
# Processing Record 35 of Set 7 | nangong
# Processing Record 36 of Set 7 | pangai
# Processing Record 37 of Set 7 | palmer
# Processing Record 38 of Set 7 | caravelas
# Processing Record 39 of Set 7 | fortuna
# Processing Record 40 of Set 7 | ambon
# Processing Record 41 of Set 7 | demba
# Processing Record 42 of Set 7 | krasnovishersk
# Processing Record 43 of Set 7 | filadelfia
# Processing Record 44 of Set 7 | nantucket
# Processing Record 45 of Set 7 | benghazi
# Processing Record 46 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 47 of Set 7 | lorengau
# Processing Record 48 of Set 7 | santa rosa
# Processing Record 49 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 7 | keffi
# Processing Record 1 of Set 8 | jacareacanga
# Processing Record 2 of Set 8 | comodoro rivadavia
# Processing Record 3 of Set 8 | norrtalje
# Processing Record 4 of Set 8 | maykain
# City not found. Skipping...
# Processing Record 5 of Set 8 | rosetta
# Processing Record 6 of Set 8 | umm lajj
# Processing Record 7 of Set 8 | namatanai
# Processing Record 8 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 9 of Set 8 | san carlos de bariloche
# Processing Record 10 of Set 8 | oranjemund
# Processing Record 11 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 8 | aksehir
# Processing Record 13 of Set 8 | mayahi
# Processing Record 14 of Set 8 | mashhad
# Processing Record 15 of Set 8 | ketchikan
# Processing Record 16 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 17 of Set 8 | luanda
# Processing Record 18 of Set 8 | vardo
# Processing Record 19 of Set 8 | klaksvik
# Processing Record 20 of Set 8 | ballina
# Processing Record 21 of Set 8 | puerto baquerizo moreno
# Processing Record 22 of Set 8 | viedma
# Processing Record 23 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 8 | vila franca do campo
# Processing Record 25 of Set 8 | broken hill
# Processing Record 26 of Set 8 | kuito
# Processing Record 27 of Set 8 | la ronge
# Processing Record 28 of Set 8 | kosa
# Processing Record 29 of Set 8 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 30 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 31 of Set 8 | omboue
# Processing Record 32 of Set 8 | kyra
# Processing Record 33 of Set 8 | san rafael
# Processing Record 34 of Set 8 | camacari
# Processing Record 35 of Set 8 | ahlat
# Processing Record 36 of Set 8 | pouembout
# Processing Record 37 of Set 8 | morrope
# Processing Record 38 of Set 8 | hereford
# Processing Record 39 of Set 8 | srednekolymsk
# Processing Record 40 of Set 8 | pisco
# Processing Record 41 of Set 8 | nisia floresta
# Processing Record 42 of Set 8 | morro bay
# Processing Record 43 of Set 8 | buzmeyin
# Processing Record 44 of Set 8 | sao paulo de olivenca
# Processing Record 45 of Set 8 | olhao
# Processing Record 46 of Set 8 | margate
# Processing Record 47 of Set 8 | maragheh
# Processing Record 48 of Set 8 | kollumerland
# City not found. Skipping...
# Processing Record 49 of Set 8 | sechura
# Processing Record 50 of Set 8 | lata
# Processing Record 1 of Set 9 | yakeshi
# Processing Record 2 of Set 9 | taoudenni
# Processing Record 3 of Set 9 | songjianghe
# Processing Record 4 of Set 9 | tiznit
# Processing Record 5 of Set 9 | bend
# Processing Record 6 of Set 9 | port hardy
# Processing Record 7 of Set 9 | ancud
# Processing Record 8 of Set 9 | jieshi
# Processing Record 9 of Set 9 | burica
# City not found. Skipping...
# Processing Record 10 of Set 9 | hami
# Processing Record 11 of Set 9 | abbeville
# Processing Record 12 of Set 9 | leua
# Processing Record 13 of Set 9 | saint-augustin
# Processing Record 14 of Set 9 | tuatapere
# Processing Record 15 of Set 9 | guerrero negro
# Processing Record 16 of Set 9 | casper
# Processing Record 17 of Set 9 | kangalassy
# Processing Record 18 of Set 9 | barstow
# Processing Record 19 of Set 9 | gat
# Processing Record 20 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 9 | arraial do cabo
# Processing Record 22 of Set 9 | honiara
# Processing Record 23 of Set 9 | komsomolskiy
# Processing Record 24 of Set 9 | solnechnyy
# Processing Record 25 of Set 9 | ilulissat
# Processing Record 26 of Set 9 | nuuk
# Processing Record 27 of Set 9 | pangnirtung
# Processing Record 28 of Set 9 | constitucion
# Processing Record 29 of Set 9 | dickinson
# Processing Record 30 of Set 9 | mabaruma
# Processing Record 31 of Set 9 | bath
# Processing Record 32 of Set 9 | bulgan
# Processing Record 33 of Set 9 | babayurt
# Processing Record 34 of Set 9 | champerico
# Processing Record 35 of Set 9 | sharlyk
# Processing Record 36 of Set 9 | russell
# Processing Record 37 of Set 9 | tigre
# Processing Record 38 of Set 9 | sao filipe
# Processing Record 39 of Set 9 | damara
# Processing Record 40 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 9 | deputatskiy
# Processing Record 42 of Set 9 | ginir
# Processing Record 43 of Set 9 | grand gaube
# Processing Record 44 of Set 9 | sorland
# Processing Record 45 of Set 9 | kahului
# Processing Record 46 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 9 | nishihara
# Processing Record 48 of Set 9 | andenes
# Processing Record 49 of Set 9 | karasburg
# Processing Record 50 of Set 9 | dudinka
# Processing Record 1 of Set 10 | kadhan
# Processing Record 2 of Set 10 | tucuman
# Processing Record 3 of Set 10 | qasigiannguit
# Processing Record 4 of Set 10 | weihe
# Processing Record 5 of Set 10 | timmins
# Processing Record 6 of Set 10 | kharp
# Processing Record 7 of Set 10 | humboldt
# Processing Record 8 of Set 10 | aripuana
# Processing Record 9 of Set 10 | dauphin
# Processing Record 10 of Set 10 | yuncheng
# Processing Record 11 of Set 10 | tazovskiy
# Processing Record 12 of Set 10 | yarada
# Processing Record 13 of Set 10 | barberton
# Processing Record 14 of Set 10 | lasem
# Processing Record 15 of Set 10 | bilibino
# Processing Record 16 of Set 10 | wuning
# Processing Record 17 of Set 10 | awjilah
# Processing Record 18 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 10 | obo
# Processing Record 20 of Set 10 | ferrol
# Processing Record 21 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 10 | roald
# Processing Record 23 of Set 10 | seybaplaya
# Processing Record 24 of Set 10 | acuna
# City not found. Skipping...
# Processing Record 25 of Set 10 | langangen
# City not found. Skipping...
# Processing Record 26 of Set 10 | zaraza
# Processing Record 27 of Set 10 | iguape
# Processing Record 28 of Set 10 | kamenka
# Processing Record 29 of Set 10 | seoul
# Processing Record 30 of Set 10 | evensk
# Processing Record 31 of Set 10 | calabozo
# Processing Record 32 of Set 10 | haapiti
# Processing Record 33 of Set 10 | okhotsk
# Processing Record 34 of Set 10 | san pelayo
# Processing Record 35 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 36 of Set 10 | nome
# Processing Record 37 of Set 10 | atar
# Processing Record 38 of Set 10 | altay
# Processing Record 39 of Set 10 | senovo
# Processing Record 40 of Set 10 | katherine
# Processing Record 41 of Set 10 | san policarpo
# Processing Record 42 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 43 of Set 10 | kautokeino
# Processing Record 44 of Set 10 | meiganga
# Processing Record 45 of Set 10 | siavonga
# Processing Record 46 of Set 10 | gilgit
# Processing Record 47 of Set 10 | labuan
# Processing Record 48 of Set 10 | sargur
# Processing Record 49 of Set 10 | antequera
# Processing Record 50 of Set 10 | faya
# Processing Record 1 of Set 11 | pinega
# Processing Record 2 of Set 11 | boa vista
# Processing Record 3 of Set 11 | kamareddi
# Processing Record 4 of Set 11 | sibolga
# Processing Record 5 of Set 11 | prince rupert
# Processing Record 6 of Set 11 | asyut
# Processing Record 7 of Set 11 | pando
# Processing Record 8 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 9 of Set 11 | eirunepe
# Processing Record 10 of Set 11 | aksu
# Processing Record 11 of Set 11 | kargala
# Processing Record 12 of Set 11 | usinsk
# Processing Record 13 of Set 11 | senneterre
# Processing Record 14 of Set 11 | salsk
# Processing Record 15 of Set 11 | camana
# Processing Record 16 of Set 11 | penzance
# Processing Record 17 of Set 11 | puerto carreno
# Processing Record 18 of Set 11 | dhule
# Processing Record 19 of Set 11 | imola
# Processing Record 20 of Set 11 | brewster
# Processing Record 21 of Set 11 | kiunga
# Processing Record 22 of Set 11 | miranda
# Processing Record 23 of Set 11 | laguna
# Processing Record 24 of Set 11 | tromso
# Processing Record 25 of Set 11 | corinto
# Processing Record 26 of Set 11 | bell ville
# Processing Record 27 of Set 11 | polunochnoye
# Processing Record 28 of Set 11 | grindavik
# Processing Record 29 of Set 11 | coquimbo
# Processing Record 30 of Set 11 | duku
# Processing Record 31 of Set 11 | ust-ilimsk
# Processing Record 32 of Set 11 | yaan
# Processing Record 33 of Set 11 | puerto escondido
# Processing Record 34 of Set 11 | akdepe
# Processing Record 35 of Set 11 | mayumba
# Processing Record 36 of Set 11 | acari
# Processing Record 37 of Set 11 | long xuyen
# Processing Record 38 of Set 11 | mizpe ramon
# City not found. Skipping...
# Processing Record 39 of Set 11 | sept-iles
# Processing Record 40 of Set 11 | cache creek
# Processing Record 41 of Set 11 | hegra
# Processing Record 42 of Set 11 | jos
# Processing Record 43 of Set 11 | santa barbara
# Processing Record 44 of Set 11 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 45 of Set 11 | jalingo
# Processing Record 46 of Set 11 | mouzakion
# City not found. Skipping...
# Processing Record 47 of Set 11 | kiruna
# Processing Record 48 of Set 11 | la mana
# Processing Record 49 of Set 11 | basco
# Processing Record 50 of Set 11 | eregli
# Processing Record 1 of Set 12 | vestmannaeyjar
# Processing Record 2 of Set 12 | marsa matruh
# Processing Record 3 of Set 12 | sao jose da coroa grande
# Processing Record 4 of Set 12 | varca
# Processing Record 5 of Set 12 | mendi
# Processing Record 6 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 7 of Set 12 | rocha
# Processing Record 8 of Set 12 | banda aceh
# Processing Record 9 of Set 12 | tarata
# Processing Record 10 of Set 12 | gloucester
# Processing Record 11 of Set 12 | baykit
# Processing Record 12 of Set 12 | mackay
# Processing Record 13 of Set 12 | buncrana
# Processing Record 14 of Set 12 | santa marta
# Processing Record 15 of Set 12 | lantana
# Processing Record 16 of Set 12 | vryburg
# Processing Record 17 of Set 12 | grand island
# Processing Record 18 of Set 12 | gobabis
# Processing Record 19 of Set 12 | charters towers
# Processing Record 20 of Set 12 | progreso
# Processing Record 21 of Set 12 | oppdal
# Processing Record 22 of Set 12 | poum
# Processing Record 23 of Set 12 | storforshei
# Processing Record 24 of Set 12 | petrovsk-zabaykalskiy
# Processing Record 25 of Set 12 | helena
# Processing Record 26 of Set 12 | hualmay
# Processing Record 27 of Set 12 | kaeo
# Processing Record 28 of Set 12 | kirakira
# Processing Record 29 of Set 12 | teahupoo
# Processing Record 30 of Set 12 | atkarsk
# Processing Record 31 of Set 12 | gashua
# Processing Record 32 of Set 12 | fairhaven
# Processing Record 33 of Set 12 | nuevitas
# Processing Record 34 of Set 12 | bensonville
# Processing Record 35 of Set 12 | napasar
# Processing Record 36 of Set 12 | hobyo
# Processing Record 37 of Set 12 | goslar
# Processing Record 38 of Set 12 | te anau
# Processing Record 39 of Set 12 | kuybysheve
# Processing Record 40 of Set 12 | saint-joseph
# Processing Record 41 of Set 12 | anadyr
# Processing Record 42 of Set 12 | panjakent
# Processing Record 43 of Set 12 | alexandria
# Processing Record 44 of Set 12 | vyazemskiy
# Processing Record 45 of Set 12 | alta floresta
# Processing Record 46 of Set 12 | vadso
# Processing Record 47 of Set 12 | san vicente
# Processing Record 48 of Set 12 | asau
# Processing Record 49 of Set 12 | abu samrah
# Processing Record 50 of Set 12 | saint anthony
# Processing Record 1 of Set 13 | ulfborg
# Processing Record 2 of Set 13 | byron bay
# Processing Record 3 of Set 13 | kapoeta
# Processing Record 4 of Set 13 | zaysan
# Processing Record 5 of Set 13 | san cristobal
# Processing Record 6 of Set 13 | panjwin
# City not found. Skipping...
# Processing Record 7 of Set 13 | takoradi
# Processing Record 8 of Set 13 | half moon bay
# Processing Record 9 of Set 13 | oudtshoorn
# Processing Record 10 of Set 13 | dehloran
# Processing Record 11 of Set 13 | almeirim
# Processing Record 12 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 13 | awbari
# Processing Record 14 of Set 13 | barraute
# Processing Record 15 of Set 13 | northam
# Processing Record 16 of Set 13 | paucartambo
# City not found. Skipping...
# Processing Record 17 of Set 13 | tortoli
# Processing Record 18 of Set 13 | klyuchi
# Processing Record 19 of Set 13 | matamoros
# Processing Record 20 of Set 13 | dingle
# Processing Record 21 of Set 13 | sudbury
# Processing Record 22 of Set 13 | khasan
# Processing Record 23 of Set 13 | zonguldak
# Processing Record 24 of Set 13 | lokoja
# Processing Record 25 of Set 13 | sur
# Processing Record 26 of Set 13 | lixourion
# Processing Record 27 of Set 13 | freeport
# Processing Record 28 of Set 13 | shiraoi
# Processing Record 29 of Set 13 | noumea
# Processing Record 30 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 31 of Set 13 | przhevalskoye
# Processing Record 32 of Set 13 | marevo
# Processing Record 33 of Set 13 | penalva
# Processing Record 34 of Set 13 | eyl
# Processing Record 35 of Set 13 | shaunavon
# Processing Record 36 of Set 13 | chapais
# Processing Record 37 of Set 13 | shostka
# Processing Record 38 of Set 13 | volchikha
# Processing Record 39 of Set 13 | campobasso
# Processing Record 40 of Set 13 | hun
# Processing Record 41 of Set 13 | nemuro
# Processing Record 42 of Set 13 | puntarenas
# Processing Record 43 of Set 13 | ajaccio
# Processing Record 44 of Set 13 | sinop
# Processing Record 45 of Set 13 | pueblo nuevo
# Processing Record 46 of Set 13 | san andres
# Processing Record 47 of Set 13 | medea
# Processing Record 48 of Set 13 | chase
# Processing Record 49 of Set 13 | atambua
# Processing Record 50 of Set 13 | labuhan
# Processing Record 1 of Set 14 | bermeo
# Processing Record 2 of Set 14 | birin
# Processing Record 3 of Set 14 | cao bang
# Processing Record 4 of Set 14 | port macquarie
# Processing Record 5 of Set 14 | mount gambier
# Processing Record 6 of Set 14 | lasa
# Processing Record 7 of Set 14 | haradok
# Processing Record 8 of Set 14 | muswellbrook
# Processing Record 9 of Set 14 | talawdi
# City not found. Skipping...
# Processing Record 10 of Set 14 | dalby
# Processing Record 11 of Set 14 | praia
# Processing Record 12 of Set 14 | taitung
# Processing Record 13 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 14 | yulara
# Processing Record 15 of Set 14 | chumikan
# Processing Record 16 of Set 14 | canyon lake
# Processing Record 17 of Set 14 | yelizavetino
# Processing Record 18 of Set 14 | bogorodskoye
# Processing Record 19 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 20 of Set 14 | maracaibo
# Processing Record 21 of Set 14 | lakes entrance
# Processing Record 22 of Set 14 | saiha
# Processing Record 23 of Set 14 | richmond
# Processing Record 24 of Set 14 | tchibanga
# Processing Record 25 of Set 14 | kailua
# Processing Record 26 of Set 14 | vila velha
# Processing Record 27 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 28 of Set 14 | mugur-aksy
# Processing Record 29 of Set 14 | sterling
# Processing Record 30 of Set 14 | neiafu
# Processing Record 31 of Set 14 | boysun
# Processing Record 32 of Set 14 | la union
# Processing Record 33 of Set 14 | vasto
# Processing Record 34 of Set 14 | kedrovyy
# Processing Record 35 of Set 14 | seymchan
# Processing Record 36 of Set 14 | altagracia de orituco
# Processing Record 37 of Set 14 | platteville
# Processing Record 38 of Set 14 | kathmandu
# Processing Record 39 of Set 14 | tuy hoa
# Processing Record 40 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 41 of Set 14 | pundaguitan
# Processing Record 42 of Set 14 | marawi
# Processing Record 43 of Set 14 | tianpeng
# Processing Record 44 of Set 14 | shitanjing
# Processing Record 45 of Set 14 | les cayes
# Processing Record 46 of Set 14 | karur
# Processing Record 47 of Set 14 | san luis obispo
# Processing Record 48 of Set 14 | muyezerskiy
# Processing Record 49 of Set 14 | asosa
# Processing Record 50 of Set 14 | kuminskiy
# Processing Record 1 of Set 15 | isla mujeres
# Processing Record 2 of Set 15 | hammerfest
# Processing Record 3 of Set 15 | elizabeth city
# Processing Record 4 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 15 | nioro
# Processing Record 6 of Set 15 | eureka
# Processing Record 7 of Set 15 | hofn
# Processing Record 8 of Set 15 | burnie
# Processing Record 9 of Set 15 | san quintin
# Processing Record 10 of Set 15 | nenjiang
# Processing Record 11 of Set 15 | atka
# City not found. Skipping...
# Processing Record 12 of Set 15 | bukachacha
# Processing Record 13 of Set 15 | praia da vitoria
# Processing Record 14 of Set 15 | abu dhabi
# Processing Record 15 of Set 15 | nabire
# Processing Record 16 of Set 15 | hamadan
# Processing Record 17 of Set 15 | mayor pablo lagerenza
# Processing Record 18 of Set 15 | bassano
# Processing Record 19 of Set 15 | miranda de ebro
# Processing Record 20 of Set 15 | aleksandrovsk-sakhalinskiy
# Processing Record 21 of Set 15 | fomboni
# Processing Record 22 of Set 15 | huancabamba
# Processing Record 23 of Set 15 | bereda
# Processing Record 24 of Set 15 | saint-andre-avellin
# Processing Record 25 of Set 15 | baloda
# Processing Record 26 of Set 15 | las vegas
# Processing Record 27 of Set 15 | sawakin
# Processing Record 28 of Set 15 | lucea
# Processing Record 29 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 30 of Set 15 | chauk
# Processing Record 31 of Set 15 | cassilandia
# Processing Record 32 of Set 15 | hondo
# Processing Record 33 of Set 15 | krasnyy oktyabr
# Processing Record 34 of Set 15 | odesskoye
# Processing Record 35 of Set 15 | inhambane
# Processing Record 36 of Set 15 | guerande
# Processing Record 37 of Set 15 | honningsvag
# Processing Record 38 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 39 of Set 15 | kukuna
# Processing Record 40 of Set 15 | vendome
# Processing Record 41 of Set 15 | saint-michel-des-saints
# Processing Record 42 of Set 15 | dutlwe
# Processing Record 43 of Set 15 | manicore
# Processing Record 44 of Set 15 | belaya gora
# Processing Record 45 of Set 15 | camacha
# Processing Record 46 of Set 15 | puerto ayacucho
# Processing Record 47 of Set 15 | miri
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 680

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Qaanaaq  77.4840  -69.3632     39.18        71          85
# 1         Dikson  73.5069   80.5464     39.29        87          31
# 2    Tuktoyaktuk  69.4541 -133.0374     45.64        95         100
# 3        Ushuaia -54.8000  -68.3000     38.86        70          20
# 4   Puerto Ayora  -0.7393  -90.3518     73.54        83          38
# 5        Esfahan  32.6572   51.6776     94.64         9           8
# 6      Coihaique -45.5752  -72.0662     44.55        53          40
# 7  Sioux Lookout  50.1001  -91.9170     77.52        35           6
# 8        Talnakh  69.4865   88.3972     55.26        93         100
# 9      Jamestown  42.0970  -79.2353     81.72        69          75
#
#    Wind Speed Country Current_Description
# 0        6.26      GL     overcast clouds
# 1       11.99      RU    scattered clouds
# 2       21.16      CA     overcast clouds
# 3       11.50      AR          few clouds
# 4       13.00      EC    scattered clouds
# 5       18.43      IR           clear sky
# 6        5.75      CL    scattered clouds
# 7       10.89      CA           clear sky
# 8        5.39      RU     overcast clouds
# 9        8.05      US       broken clouds

# %%
# Arrange columns of df in order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current_Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Qaanaaq      GL  77.4840  -69.3632     39.18        71          85
# 1         Dikson      RU  73.5069   80.5464     39.29        87          31
# 2    Tuktoyaktuk      CA  69.4541 -133.0374     45.64        95         100
# 3        Ushuaia      AR -54.8000  -68.3000     38.86        70          20
# 4   Puerto Ayora      EC  -0.7393  -90.3518     73.54        83          38
# 5        Esfahan      IR  32.6572   51.6776     94.64         9           8
# 6      Coihaique      CL -45.5752  -72.0662     44.55        53          40
# 7  Sioux Lookout      CA  50.1001  -91.9170     77.52        35           6
# 8        Talnakh      RU  69.4865   88.3972     55.26        93         100
# 9      Jamestown      US  42.0970  -79.2353     81.72        69          75
#
#    Wind Speed Current_Description
# 0        6.26     overcast clouds
# 1       11.99    scattered clouds
# 2       21.16     overcast clouds
# 3       11.50          few clouds
# 4       13.00    scattered clouds
# 5       18.43           clear sky
# 6        5.75    scattered clouds
# 7       10.89           clear sky
# 8        5.39     overcast clouds
# 9        8.05       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
